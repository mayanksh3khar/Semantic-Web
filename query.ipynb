# %% [markdown]
# # SPARQL query

# %%
import pandas as pd
import numpy as np
import haversine as hs
import rdflib
from SPARQLWrapper import SPARQLWrapper, JSON, CSV

# %% [markdown]
# ### Input parameters

# %%
#latitude
#longitude
#radius

# %% [markdown]
# #### Example setting

# %%
# endpoint
endpoint = 'https://query.wikidata.org/sparql'

# query variables
latitude  = '49.487777777' # Mannheim
longitude = '8.466111111'  # Mannheim

#latitude  = '49.410833333333'  # Heidelberg
#longitude = '8.7063888888889'  # Heidelberg


#obj_class = '' 
radius    = '15'
limit     = '3000'

# %% [markdown]
# ### Query
#
# Description of the retrieved variables in the sparql query
# - ?x : Resourcee of the thing (a specific street, chruch, etc.) we search
#     - ?xLabel : Label of that resource
#     - ?otherLocation : Coordinates of the respective resource
# - ?somebody : identifier of the person the resource is named after
#     - ?somebodyLabel : Label of that person
# - ?classLabel : What kind of thing are we looking at (church, street, venue...)
# - ?dist : distance between current location and the location of the retrieved resource

# %%
# Query for the table
query = '''
        prefix bd:       <http://www.bigdata.com/rdf#>
        prefix geo:      <http://www.opengis.net/ont/geosparql#>
        prefix wd:       <http://www.wikidata.org/entity/>
        prefix wdt:      <http://www.wikidata.org/prop/direct/>
        prefix wikibase: <http://wikiba.se/ontology#>


        SELECT ?xLabel ?x ?somebodyLabel ?somebody ?otherLocation 
               (GROUP_CONCAT(?classLabel; separator=', ') AS ?classdescription)
        WHERE
        {{
          BIND('Point({longitude} {latitude})'^^geo:wktLiteral AS ?currentLocation).
          SERVICE wikibase:around {{
              # ?x wdt:P625 ?otherLocation. 
              bd:serviceParam wikibase:center ?currentLocation. 
              bd:serviceParam wikibase:radius '{radius}'. 
          }}
          # x is named after
          # ?x wdt:P138 ?somebody .
          
          # that somebody is a human
          # ?somebody wdt:P31 wd:Q5 .

          # which Class is x (e.g. Street, church)
          # ?x wdt:P31  ?class . 
          
          # the class has a german label 
          # ?class rdfs:label ?classLabel .
          FILTER( lang(?classLabel) = "de" )
          
          # Retrieve Labels
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "de". }} 
          
        }} 
        GROUP BY ?xLabel ?x ?somebodyLabel ?somebody ?otherLocation
        LIMIT {limit}
        
        '''.format(longitude = longitude, latitude = latitude, radius = radius, limit = limit)
print(query)
# Out:
#         prefix bd:       <http://www.bigdata.com/rdf#>
#         prefix geo:      <http://www.opengis.net/ont/geosparql#>
#         prefix wd:       <http://www.wikidata.org/entity/>
#         prefix wdt:      <http://www.wikidata.org/prop/direct/>
#         prefix wikibase: <http://wikiba.se/ontology#>
#
#
#         SELECT ?xLabel ?x ?somebodyLabel ?somebody ?otherLocation
#                (GROUP_CONCAT(?classLabel; separator=', ') AS ?classdescription)
#         WHERE
#         {
#           BIND('Point(8.466111111 49.487777777)'^^geo:wktLiteral AS ?currentLocation).
#           SERVICE wikibase:around {
#               ?x wdt:P625 ?otherLocation.
#               bd:serviceParam wikibase:center ?currentLocation.
#               bd:serviceParam wikibase:radius '15'.
#           }
#           # x is named after
#           ?x wdt:P138 ?somebody .
#
#           # that somebody is a human
#           ?somebody wdt:P31 wd:Q5 .
#
#           # which Class is x (e.g. Street, church)
#           ?x wdt:P31  ?class .
#
#           # the class has a german label
#           ?class rdfs:label ?classLabel .
#           FILTER( lang(?classLabel) = "de" )
#
#           # Retrieve Labels
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "de". }
#
#         }
#         GROUP BY ?xLabel ?x ?somebodyLabel ?somebody ?otherLocation
#         LIMIT 3000

# %%
# Query for the map
# mapQuery = '''
#<iframe style="width: 80vw; height: 50vh; border: none;" 
#src="https://query.wikidata.org/embed.html#%23defaultView%3AMap%0A%20%20%20%20%20%20%20%20
#prefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0A%20%20%20%20%20%20%20%20
#prefix%20geo%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.opengis.net%2Font%2Fgeosparql%23%3E%0A%20%20%20%20%20%20%20%20
#prefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0A%20%20%20%20%20%20%20%20
#prefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0A%20%20%20%20%20%20%20%20
#prefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0A%20%20%20%20%20%20%20%20
#SELECT%20%3FxLabel%20%3Fx%20%3FsomebodyLabel%20%3Fsomebody%20%3FclassLabel%20%3FotherLocation%20%3Fdist%0A%20%20%20%20%20%20%20%20
#WHERE%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20
#BIND('Point({longitude}%20{latitude})'%5E%5Egeo%3AwktLiteral%20AS%20%3FcurrentLocation).%0A%20%20%20%20%20%20%20%20%20%20
#SERVICE%20wikibase%3Aaround%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP625%20%3FotherLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20
#bd%3AserviceParam%20wikibase%3Acenter%20%3FcurrentLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20
#bd%3AserviceParam%20wikibase%3Aradius%20'{radius}'.%20%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%23%20
#x%20is%20named%20after%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP138%20%3Fsomebody%20.%0A%0A%20%20%20%20%20%20%20%20%20%20%23%20
#which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP31%20%20%3Fclass%20.%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20
#x%20is%20a%20Street%0A%20%20%20%20%20%20%20%20%20%20%23%3Fx%20wdt%3AP31%20wd%3AQ79007%20.%0A%0A%20%20%20%20%20%20%20%20%20%20%23%20
#hat%20Staat%20Deutschland%0A%20%20%20%20%20%20%20%20%20%20%23%20%3Fx%20wdt%3AP17%20%20%3FQ183%20.%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20Retrieve%20Labels%0A%20%20%20%20%20%20%20%20%20%20
#SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22de%22.%20%7D%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20
#Compute%20Distance%0A%20%20%20%20%20%20%20%20%20%20%23%20
#BIND(geof%3Adistance(%3FotherLocation%2C%20%3FcurrentLocation)%20as%20%3Fdist)%20%0A%20%20%20%20%20%20%20%20%7D%20%0A%0A%20%20%20%20%20%20%20%20
#LIMIT%20{limit}%0A%20%20%20%20%20%20%20%20%23ORDER%20BY%20%3Fdist" 
#referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>'''.format(longitude = longitude, latitude = latitude, radius = radius, limit = limit)

mapQuery = '''
<iframe style="width: 80vw; height: 50vh; border: none;" src="https://query.wikidata.org/embed.html#%23defaultView%3AMap%0A%20%20%20%20%20%20%20%20prefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0A%20%20%20%20%20%20%20%20prefix%20geo%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.opengis.net%2Font%2Fgeosparql%23%3E%0A%20%20%20%20%20%20%20%20prefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0A%20%20%20%20%20%20%20%20prefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0A%20%20%20%20%20%20%20%20prefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0A%20%20%20%20%20%20%20%20SELECT%20%3FxLabel%20%3Fx%20%3FsomebodyLabel%20%3Fsomebody%20%3FotherLocation%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20(GROUP_CONCAT(%3FclassLabel%3B%20separator%3D'%2C%20')%20AS%20%3Fclassdescription)%0A%20%20%20%20%20%20%20%20WHERE%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20BIND('Point({longitude}%20{latitude})'%5E%5Egeo%3AwktLiteral%20AS%20%3FcurrentLocation).%0A%20%20%20%20%20%20%20%20%20%20SERVICE%20wikibase%3Aaround%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP625%20%3FotherLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20bd%3AserviceParam%20wikibase%3Acenter%20%3FcurrentLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20bd%3AserviceParam%20wikibase%3Aradius%20'{radius}'.%20%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%23%20x%20is%20named%20after%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP138%20%3Fsomebody%20.%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20that%20somebody%20is%20a%20human%0A%20%20%20%20%20%20%20%20%20%20%3Fsomebody%20wdt%3AP31%20wd%3AQ5%20.%0A%0A%20%20%20%20%20%20%20%20%20%20%23%20which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP31%20%20%3Fclass%20.%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20the%20class%20has%20a%20german%20label%20%0A%20%20%20%20%20%20%20%20%20%20%3Fclass%20rdfs%3Alabel%20%3FclassLabel%20.%0A%20%20%20%20%20%20%20%20%20%20FILTER(%20lang(%3FclassLabel)%20%3D%20%22de%22%20)%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20Retrieve%20Labels%0A%20%20%20%20%20%20%20%20%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22de%22.%20%7D%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%7D%20%0A%20%20%20%20%20%20%20%20GROUP%20BY%20%3FxLabel%20%3Fx%20%3FsomebodyLabel%20%3Fsomebody%20%3FotherLocation%0A%20%20%20%20%20%20%20%20LIMIT%20{limit}%0A%20%20%20%20%20%20%20%20" referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>
'''.format(longitude = longitude, latitude = latitude, radius = radius, limit = limit)

mapQuery
# Out:
# '\n<iframe style="width: 80vw; height: 50vh; border: none;" src="https://query.wikidata.org/embed.html#%23defaultView%3AMap%0A%20%20%20%20%20%20%20%20prefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0A%20%20%20%20%20%20%20%20prefix%20geo%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.opengis.net%2Font%2Fgeosparql%23%3E%0A%20%20%20%20%20%20%20%20prefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0A%20%20%20%20%20%20%20%20prefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0A%20%20%20%20%20%20%20%20prefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0A%20%20%20%20%20%20%20%20SELECT%20%3FxLabel%20%3Fx%20%3FsomebodyLabel%20%3Fsomebody%20%3FotherLocation%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20(GROUP_CONCAT(%3FclassLabel%3B%20separator%3D\'%2C%20\')%20AS%20%3Fclassdescription)%0A%20%20%20%20%20%20%20%20WHERE%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20BIND(\'Point(8.466111111%2049.487777777)\'%5E%5Egeo%3AwktLiteral%20AS%20%3FcurrentLocation).%0A%20%20%20%20%20%20%20%20%20%20SERVICE%20wikibase%3Aaround%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP625%20%3FotherLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20bd%3AserviceParam%20wikibase%3Acenter%20%3FcurrentLocation.%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20bd%3AserviceParam%20wikibase%3Aradius%20\'15\'.%20%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%23%20x%20is%20named%20after%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP138%20%3Fsomebody%20.%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20that%20somebody%20is%20a%20human%0A%20%20%20%20%20%20%20%20%20%20%3Fsomebody%20wdt%3AP31%20wd%3AQ5%20.%0A%0A%20%20%20%20%20%20%20%20%20%20%23%20which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20%20%20%20%20%20%3Fx%20wdt%3AP31%20%20%3Fclass%20.%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20the%20class%20has%20a%20german%20label%20%0A%20%20%20%20%20%20%20%20%20%20%3Fclass%20rdfs%3Alabel%20%3FclassLabel%20.%0A%20%20%20%20%20%20%20%20%20%20FILTER(%20lang(%3FclassLabel)%20%3D%20%22de%22%20)%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%23%20Retrieve%20Labels%0A%20%20%20%20%20%20%20%20%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22de%22.%20%7D%20%0A%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%7D%20%0A%20%20%20%20%20%20%20%20GROUP%20BY%20%3FxLabel%20%3Fx%20%3FsomebodyLabel%20%3Fsomebody%20%3FotherLocation%0A%20%20%20%20%20%20%20%20LIMIT%203000%0A%20%20%20%20%20%20%20%20" referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>\n'

# %%
# Initializing SPARQL Wrapper and querying
sparql = SPARQLWrapper(endpoint)
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
# Initializing function to compute ditance
def cumputeDistance(newpoint, currentLongitude, currentLatitude):
    newLocation     = np.array([float(x) for x in newpoint[6:-1].split(' ')][::-1])
    currentLocation = np.array([float(longitude), float(latitude)][::-1])
    distance = hs.haversine(newLocation,currentLocation)
    return distance

# Results
df = pd.DataFrame(results['results']['bindings'])
for col in df.columns:
    df[col] = df[col].apply(lambda x: x['value'])

# compute ditance    
df['distance'] = df['otherLocation'].apply(lambda point: cumputeDistance(point, longitude, latitude))

# Sort according to distance
df = df.sort_values(by=['distance'])

df.head(10)
# Out:
#                                            xLabel  \
# 16                                 Jesuitenkirche
# 52  Otto-Selz-Institut für Angewandte Psychologie
# 63              Karl-Friedrich-Gymnasium Mannheim
# 58                         Konrad-Adenauer-Brücke
# 47                                   Lutherkirche
# 14                                     St. Ludwig
# 27                              Melanchthonkirche
# 30                            St.-Bernhard-Kirche
# 11                                   Lutherkirche
# 0                    Liselotte-Gymnasium Mannheim
#
#                                            x            somebodyLabel  \
# 16    http://www.wikidata.org/entity/Q538329      Ignatius von Loyola
# 52  http://www.wikidata.org/entity/Q17513791                Otto Selz
# 63   http://www.wikidata.org/entity/Q1729755           Karl Friedrich
# 58   http://www.wikidata.org/entity/Q1781874          Konrad Adenauer
# 47   http://www.wikidata.org/entity/Q1690432            Martin Luther
# 14   http://www.wikidata.org/entity/Q2320389               Ludwig IX.
# 27   http://www.wikidata.org/entity/Q1354638      Philipp Melanchthon
# 30   http://www.wikidata.org/entity/Q2316011             Bernhard II.
# 11   http://www.wikidata.org/entity/Q1665776            Martin Luther
# 0   http://www.wikidata.org/entity/Q66459147  Liselotte von der Pfalz
#
#                                   somebody                  otherLocation  \
# 16   http://www.wikidata.org/entity/Q44281            Point(8.461 49.486)
# 52   http://www.wikidata.org/entity/Q74856      Point(8.468931 49.480875)
# 63  http://www.wikidata.org/entity/Q213671         Point(8.47603 49.4821)
# 58    http://www.wikidata.org/entity/Q2492  Point(8.45638889 49.48111111)
# 47    http://www.wikidata.org/entity/Q9554         Point(8.46392 49.4987)
# 14     http://www.wikidata.org/entity/Q346         Point(8.44853 49.4801)
# 27   http://www.wikidata.org/entity/Q76325           Point(8.4808 49.498)
# 30  http://www.wikidata.org/entity/Q523903         Point(8.47659 49.5003)
# 11    http://www.wikidata.org/entity/Q9554         Point(8.44479 49.4811)
# 0    http://www.wikidata.org/entity/Q57221         Point(8.485 49.478417)
#
#                        classdescription  distance
# 16       Kirchengebäude, Jesuitenkirche  0.418791
# 52  Forschungseinrichtung, Organisation  0.794126
# 63                            Gymnasium  0.954981
# 58                        Straßenbrücke  1.021164
# 47   Kirchengebäude, religiöses Gebäude  1.224765
# 14                       Kirchengebäude  1.530317
# 27                       Kirchengebäude  1.554846
# 30                       Kirchengebäude  1.584801
# 11                       Kirchengebäude  1.709849
# 0                                Schule  1.716213

# %% [markdown]
# ### Distance Test

# %%
## Test computing distance between two points

# Coordinates of Christuskirche  Q1087367
p1 = 'Point(8.4807 49.4846)'

# Coordinates of St-Pius-Kirche Q1405432
p2 = 'Point(8.51166 49.4798)'

loc1 = np.array([float(x) for x in p1[6:-1].split(' ')][::-1])
loc2 = np.array([float(x) for x in p2[6:-1].split(' ')][::-1])

# Calculating distance using haversine package | km per default
distance = hs.haversine(loc1,loc2)  
print('Calculated distance:        ', distance)
print('Sparql distance in Wikidata: 2.299291884545297')

# Link to control query in wikidata
# https://query.wikidata.org/#prefix%20unit%3A%20%3Chttp%3A%2F%2Fqudt.org%2Fvocab%2Funit%23%3E%0A%0ASELECT%20%3Fdist%0AWHERE%20%7B%0A%20%20%23%20Berlin%20coordinates%0A%20%20wd%3AQ1405432%20wdt%3AP625%20%3Floc1.%20%0A%20%20wd%3AQ1087367%20wdt%3AP625%20%3Floc2%20.%0A%20%20%0A%20%20BIND%28geof%3Adistance%28%3Floc1%2C%20%3Floc2%2C%20unit%3AKilometer%29%20as%20%3Fdist%29%20%0A%7D%20%0AORDER%20BY%20%3Fdist
# Out:
# Calculated distance:         2.2994056883957326
# Sparql distance in Wikidata: 2.299291884545297

# %% [markdown]
# # 2.  Query: Abstract
#
# Difficulties to retrieve <br>
# #?s dbo:abstract ?abstract . <br>
# #FILTER( lang(?abstract) = "en" )

# %%
# parameters to hand over
somebody = 'http://www.wikidata.org/entity/Q5879'  # Goethe
somebodysName = 'Martin Luther'  #linking from result set above. Necessary if no result is found
somebodysName = 'Mark Twain'

# %%
# Query for abstract
queryAbstract = '''
        prefix owl:  <http://www.w3.org/2002/07/owl#>
        prefix dbo:  <http://dbpedia.org/ontology>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT ?name ?comment 
        
        WHERE {{
             # ?s owl:sameAs <{somebody}> .
             # ?s foaf:name ?name .
             # ?s rdfs:comment ?comment.
             FILTER( lang(?comment) = "en" )
        }}
        '''.format(somebody = somebody)
print(queryAbstract)
# Out:
#         prefix owl:  <http://www.w3.org/2002/07/owl#>
#         prefix dbo:  <http://dbpedia.org/ontology>
#         prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
#         SELECT ?name ?comment # ?abstract
#
#         WHERE {
#              ?s owl:sameAs <http://www.wikidata.org/entity/Q5879> .
#              ?s foaf:name ?name .
#              ?s rdfs:comment ?comment.
#              FILTER( lang(?comment) = "en" )
#         }

# %%
# Query which is searching for persons giving a string containing the requested name
queryAbstractNameSearch = '''
        prefix owl:  <http://www.w3.org/2002/07/owl#>
        prefix dbo:  <http://dbpedia.org/ontology/>
        prefix foaf: <http://xmlns.com/foaf/0.1/>
        prefix rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT DISTINCT ?name ?comment 

        WHERE {{
            # ?s rdf:type ?type .
            FILTER ( ?type = foaf:Person || ?type = dbo:Person )
            # ?s foaf:name ?name .
            FILTER ( regex(?name, "{somebodysName}") ) 
            # ?s rdfs:comment ?comment.
            FILTER( lang(?comment) = "en" )          
        }}
        '''.format(somebodysName = somebodysName)

# %%
# Query for DBPedia
endpointDBp = 'http://dbpedia.org/sparql'
sparqlDBp = SPARQLWrapper(endpointDBp)
sparqlDBp.setQuery(queryAbstract)
sparqlDBp.setReturnFormat(JSON)
resultAbstract = sparqlDBp.query().convert()

# %%
resultAbstract['results']['bindings'][0]['comment']['value']
# Out:
# 'Johann Wolfgang (von) Goethe (/ˈɡɜːrtə/; German: [ˈjoːhan ˈvɔlfɡaŋ ˈɡøːtə] ; 28 August 1749 – 22 March 1832) was a German writer and statesman. His body of work includes epic and lyric poetry written in a variety of metres and styles; prose and verse dramas; memoirs; an autobiography; literary and aesthetic criticism; treatises on botany, anatomy, and colour; and four novels. In addition, numerous literary and scientific fragments, more than 10,000 letters, and nearly 3,000 drawings by him exist.'

# %%
# Trying to retrieve the comment.
    # In case there is none or the person was not found. Return the error message.
if resultAbstract['results']['bindings'] != []:
    # Appending names an their comments in case of several results
    comment = ''
    results = resultAbstract['results']['bindings']
    for res in results:
        comment += res['name']['value']
        comment += ':\n'
        comment += res['comment']['value']
        comment += '\n\n'
else:
    comment = 'Sorry, there is no description of {}.'.format(somebodysName)
    
print(comment[:1000])
# Out:
# Johann Wolfgang von Goethe:
# Johann Wolfgang (von) Goethe (/ˈɡɜːrtə/; German: [ˈjoːhan ˈvɔlfɡaŋ ˈɡøːtə] ; 28 August 1749 – 22 March 1832) was a German writer and statesman. His body of work includes epic and lyric poetry written in a variety of metres and styles; prose and verse dramas; memoirs; an autobiography; literary and aesthetic criticism; treatises on botany, anatomy, and colour; and four novels. In addition, numerous literary and scientific fragments, more than 10,000 letters, and nearly 3,000 drawings by him exist.
#
# Johann Wolfgang (von) Goethe:
# Johann Wolfgang (von) Goethe (/ˈɡɜːrtə/; German: [ˈjoːhan ˈvɔlfɡaŋ ˈɡøːtə] ; 28 August 1749 – 22 March 1832) was a German writer and statesman. His body of work includes epic and lyric poetry written in a variety of metres and styles; prose and verse dramas; memoirs; an autobiography; literary and aesthetic criticism; treatises on botany, anatomy, and colour; and four novels. In addition, numerous literary and scientific fragments, mor

# %% [markdown]
# # 3. Query: All named

# %%
queryAllResources = '''
    prefix bd:       <http://www.bigdata.com/rdf#>
    prefix wd:       <http://www.wikidata.org/entity/>
    prefix wdt:      <http://www.wikidata.org/prop/direct/>
    prefix wikibase: <http://wikiba.se/ontology#>


    SELECT ?x ?xLabel ?somebodyLabel ?Location ?countryLabel
        (GROUP_CONCAT(?classlabel; separator=', ') AS ?classdescription)

    WHERE {{
      # x is named after
      # ?x wdt:P138 <{somebody}> ;

      # x has location
         wdt:P625 ?Location ;

      # which Class is x (e.g. Street, church)
         wdt:P31  ?class . 
         
      # get somebodys name (needed to display name on top of level 2)
      # ?x wdt:P138 ?somebody.

      # the class has a german label 
      # ?class rdfs:label ?classlabel .
      FILTER ( lang(?classlabel) = "de" )

      # located in Germany, Austria, or Switzerland
      # ?x wdt:P17 ?country .
      FILTER ( ?country = wd:Q39 || ?country = wd:Q40 || ?country = wd:Q183 )

      # Retrieve Labels
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "de". }}

    }}
    GROUP BY ?x ?xLabel ?somebodyLabel ?Location ?countryLabel
    LIMIT 1000

'''.format(somebody=somebody)
print(queryAllResources)
# Out:
#     prefix bd:       <http://www.bigdata.com/rdf#>
#     prefix wd:       <http://www.wikidata.org/entity/>
#     prefix wdt:      <http://www.wikidata.org/prop/direct/>
#     prefix wikibase: <http://wikiba.se/ontology#>
#
#
#     SELECT ?x ?xLabel ?somebodyLabel ?Location ?countryLabel
#         (GROUP_CONCAT(?classlabel; separator=', ') AS ?classdescription)
#
#     WHERE {
#       # x is named after
#       ?x wdt:P138 <http://www.wikidata.org/entity/Q5879> ;
#
#       # x has location
#          wdt:P625 ?Location ;
#
#       # which Class is x (e.g. Street, church)
#          wdt:P31  ?class .
#
#       # get somebodys name (needed to display name on top of level 2)
#       ?x wdt:P138 ?somebody.
#
#       # the class has a german label
#       ?class rdfs:label ?classlabel .
#       FILTER ( lang(?classlabel) = "de" )
#
#       # located in Germany, Austria, or Switzerland
#       ?x wdt:P17 ?country .
#       FILTER ( ?country = wd:Q39 || ?country = wd:Q40 || ?country = wd:Q183 )
#
#       # Retrieve Labels
#       SERVICE wikibase:label { bd:serviceParam wikibase:language "de". }
#
#     }
#     GROUP BY ?x ?xLabel ?somebodyLabel ?Location ?countryLabel
#     LIMIT 1000

# %%
# Query which is searching for persons giving a string containing the requested name
queryAllResourcesNameSearch = '''
    prefix bd:       <http://www.bigdata.com/rdf#>
    prefix wd:       <http://www.wikidata.org/entity/>
    prefix wdt:      <http://www.wikidata.org/prop/direct/>
    prefix wikibase: <http://wikiba.se/ontology#>


    SELECT ?x ?xLabel ?Location ?countryLabel
        (GROUP_CONCAT (DISTINCT ?classLabel; separator=', ') AS ?classdescription)

    WHERE {{
      # ?s wdt:P31 wd:Q5 ;
         rdfs:label ?sLabel .
      FILTER (regex(?sLabel, "{somebodysName}") ) 
    
      # x is named after
      # ?x wdt:P138 ?s ;

      # x has location
         wdt:P625 ?Location ;

      # which Class is x (e.g. Street, church)
         wdt:P31  ?class . 

      # the class has a german label 
      # ?class rdfs:label ?classLabel .
      FILTER ( lang(?classLabel) = "en" )

      # located in Germany, Austria, or Switzerland
      # ?x wdt:P17 ?country .
      FILTER ( ?country = wd:Q39 || ?country = wd:Q40 || ?country = wd:Q183 )

      # Retrieve Labels
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}

    }}
    GROUP BY ?x ?xLabel ?Location ?countryLabel
    LIMIT 1000

'''.format(somebodysName=somebodysName)
print(queryAllResourcesNameSearch)
# Out:
#     prefix bd:       <http://www.bigdata.com/rdf#>
#     prefix wd:       <http://www.wikidata.org/entity/>
#     prefix wdt:      <http://www.wikidata.org/prop/direct/>
#     prefix wikibase: <http://wikiba.se/ontology#>
#
#
#     SELECT ?x ?xLabel ?Location ?countryLabel
#         (GROUP_CONCAT (DISTINCT ?classLabel; separator=', ') AS ?classdescription)
#
#     WHERE {
#       ?s wdt:P31 wd:Q5 ;
#          rdfs:label ?sLabel .
#       FILTER (regex(?sLabel, "Mark Twain") )
#
#       # x is named after
#       ?x wdt:P138 ?s ;
#
#       # x has location
#          wdt:P625 ?Location ;
#
#       # which Class is x (e.g. Street, church)
#          wdt:P31  ?class .
#
#       # the class has a german label
#       ?class rdfs:label ?classLabel .
#       FILTER ( lang(?classLabel) = "en" )
#
#       # located in Germany, Austria, or Switzerland
#       ?x wdt:P17 ?country .
#       FILTER ( ?country = wd:Q39 || ?country = wd:Q40 || ?country = wd:Q183 )
#
#       # Retrieve Labels
#       SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#
#     }
#     GROUP BY ?x ?xLabel ?Location ?countryLabel
#     LIMIT 1000

# %%
sparqlAll = SPARQLWrapper(endpoint)
sparqlAll.setQuery(queryAllResources)
sparqlAll.setReturnFormat(JSON)
resultsAll = sparqlAll.query().convert()

# %%
resultsAll
# Out:
# {'head': {'vars': ['x',
#    'xLabel',
#    'somebodyLabel',
#    'Location',
#    'countryLabel',
#    'classdescription']},
#  'results': {'bindings': [{'x': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6215551'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann-Wolfgang-von-Goethe-Gymnasium Chemnitz'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.942076 50.815887)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Schule, Schulgebäude'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q19695856'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Schule Flensburg'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.44289 54.7864)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'Schule, weiterführende Schule, Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q89492027'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheweg'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.70133 50.93311)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'Sackgasse, Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534093'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethe-Brunnen'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.2885 50.8984)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Park, Brunnen'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16831607'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethepark'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.59054 52.677105)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Park'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q99727462'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.441383 51.175942)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q100263730'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheplatz'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.72349 52.37268)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q100263732'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.72795 52.37416)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q100936591'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.848995 51.128296)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101415647'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethering'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.166851882 50.652391243)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96745759'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.45713 51.62174)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q97466281'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethestraße (Diepholz)'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.3813607 52.6119962)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q97487943'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.436993 52.552431)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534150'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethe-Theater'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.8639 51.3883)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Theater'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q71727917'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheanum'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.62044 47.486)'},
#     'countryLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Schweiz'},
#     'classdescription': {'type': 'literal',
#      'value': 'Theater, Mehrzweckhalle'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30447692'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Ibn-Rushd-Goethe-Moschee'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.34944444 52.525)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Moschee'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30447692'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Ibn-Rushd-Goethe-Moschee'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Averroës'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.34944444 52.525)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Moschee'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534213'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethes Gartenhaus'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.3369 50.9761)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'Museum, Einfamilienwohnhaus'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q74425396'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Gymnasium Regensburg'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.073798 49.018051)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534237'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(6.47598 50.8002)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q22290863'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.315730555 52.508886111)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27162515'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethegasse'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(16.366915 48.203928)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Österreich'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28053520'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.9001 54.1095)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q52592248'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.44526 48.77222)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q61001497'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheallee'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.7953 51.0577)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q65768651'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.991655 51.524846)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q72662608'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.78386 51.1193)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q89280287'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestraße'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.90629 50.82352)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Innerortsstraße'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43465785'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheplatz'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.5493947 51.7361062)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Platz'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49321958'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheplatz'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.90757 50.82208)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Platz, Gesamtanlage'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534095'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethe-Denkmal'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.3764 52.5138)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Statue, Denkmal'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q48118550'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethehäuschen auf dem Kickelhahn'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.8792 50.6664)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Holzhaus'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534232'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethestein'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.16017 50.0625)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Skulptur'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q50662'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Universität Frankfurt am Main'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.651388888 50.119444444)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'staatliche Universität'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q659654'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheanum'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.620278 47.486111)'},
#     'countryLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Schweiz'},
#     'classdescription': {'type': 'literal',
#      'value': 'Schulgebäude, Mehrzweckhalle, Verwaltungsgebäude, religiöses Gebäude'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q22555'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Gymnasium Germersheim'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.37341944 49.21316111)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1286167'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethegymnasium Hildesheim'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.95667 52.1494)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1303960'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Schule Bochum'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.22 51.4864)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534105'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Gymnasium'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.62027778 49.69166667)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534107'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Gymnasium'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.3216 52.4873)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'Gymnasium, humanistisches Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534116'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Gymnasium Ibbenbüren'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.72139 52.275)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Gymnasium'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q547717'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheturm'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.711333333 50.089)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Aussichtsturm'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1507756'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goethewarte'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.24444 50.0931)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Aussichtsturm'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534244'},
#     'xLabel': {'xml:lang': 'de', 'type': 'literal', 'value': 'Goetheweg'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.233056 47.256944)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Österreich'},
#     'classdescription': {'type': 'literal', 'value': 'Themenwanderweg'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534100'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe-Freilichtbühne Porta Westfalica'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(8.90969 52.247)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Freilichtbühne'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1534156'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Goethe- und Schiller-Archiv'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.3338 50.9831)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Literaturarchiv'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49350725'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Herrenwalder Straße 1; 2'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.64875 50.87068)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal',
#      'value': 'ehemaliges Schulgebäude'}},
#    {'x': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q15857849'},
#     'xLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Grundschule Pritzerbe „Johann Wolfgang von Goethe“'},
#     'somebodyLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Johann Wolfgang von Goethe'},
#     'Location': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.456924 52.494812)'},
#     'countryLabel': {'xml:lang': 'de',
#      'type': 'literal',
#      'value': 'Deutschland'},
#     'classdescription': {'type': 'literal', 'value': 'Grundschule'}}]}}

# %%
# Results
dfAll = pd.DataFrame(resultsAll['results']['bindings'])
for col in dfAll.columns:
    dfAll[col] = dfAll[col].apply(lambda x: x['value'])

# compute ditance    
dfAll['distance'] = dfAll['Location'].apply(lambda point: cumputeDistance(point, longitude, latitude))

# Sort according to distance
dfAll = dfAll.sort_values(by=['distance'])

dfAll.head(10)
# Out:
#                                            x  \
# 38   http://www.wikidata.org/entity/Q1534105
# 35     http://www.wikidata.org/entity/Q22555
# 32   http://www.wikidata.org/entity/Q1534232
# 41    http://www.wikidata.org/entity/Q547717
# 42   http://www.wikidata.org/entity/Q1507756
# 33     http://www.wikidata.org/entity/Q50662
# 19   http://www.wikidata.org/entity/Q1534237
# 31  http://www.wikidata.org/entity/Q48118550
# 23  http://www.wikidata.org/entity/Q52592248
# 34    http://www.wikidata.org/entity/Q659654
#
#                                   xLabel               somebodyLabel  \
# 38                      Goethe-Gymnasium  Johann Wolfgang von Goethe
# 35          Goethe-Gymnasium Germersheim  Johann Wolfgang von Goethe
# 32                           Goethestein  Johann Wolfgang von Goethe
# 41                            Goetheturm  Johann Wolfgang von Goethe
# 42                           Goethewarte  Johann Wolfgang von Goethe
# 33  Goethe-Universität Frankfurt am Main  Johann Wolfgang von Goethe
# 19                          Goethestraße  Johann Wolfgang von Goethe
# 31     Goethehäuschen auf dem Kickelhahn  Johann Wolfgang von Goethe
# 23                          Goethestraße  Johann Wolfgang von Goethe
# 34                            Goetheanum  Johann Wolfgang von Goethe
#
#                            Location countryLabel  \
# 38    Point(8.62027778 49.69166667)  Deutschland
# 35    Point(8.37341944 49.21316111)  Deutschland
# 32           Point(8.16017 50.0625)  Deutschland
# 41        Point(8.711333333 50.089)  Deutschland
# 42           Point(8.24444 50.0931)  Deutschland
# 33  Point(8.651388888 50.119444444)  Deutschland
# 19           Point(6.47598 50.8002)  Deutschland
# 31           Point(10.8792 50.6664)  Deutschland
# 23         Point(11.44526 48.77222)  Deutschland
# 34        Point(7.620278 47.486111)      Schweiz
#
#                                      classdescription    distance
# 38                                          Gymnasium   25.248516
# 35                                          Gymnasium   31.265455
# 32                                           Skulptur   67.576896
# 41                                      Aussichtsturm   69.131842
# 42                                      Aussichtsturm   69.164213
# 33                             staatliche Universität   71.485674
# 19                                    Innerortsstraße  203.478314
# 31                                           Holzhaus  216.379562
# 23                                    Innerortsstraße  230.884789
# 34  Schulgebäude, Mehrzweckhalle, Verwaltungsgebäu...  231.135932

# %%
dfAll
# Out:
#                                             x  \
# 39    http://www.wikidata.org/entity/Q1534105
# 36      http://www.wikidata.org/entity/Q22555
# 31    http://www.wikidata.org/entity/Q1534232
# 34     http://www.wikidata.org/entity/Q547717
# 35    http://www.wikidata.org/entity/Q1507756
# 32      http://www.wikidata.org/entity/Q50662
# 18    http://www.wikidata.org/entity/Q1534237
# 30   http://www.wikidata.org/entity/Q48118550
# 22   http://www.wikidata.org/entity/Q52592248
# 33     http://www.wikidata.org/entity/Q659654
# 6    http://www.wikidata.org/entity/Q71727917
# 38    http://www.wikidata.org/entity/Q1303960
# 3     http://www.wikidata.org/entity/Q1534093
# 16    http://www.wikidata.org/entity/Q1534213
# 44    http://www.wikidata.org/entity/Q1534156
# 17   http://www.wikidata.org/entity/Q74425396
# 13   http://www.wikidata.org/entity/Q96745759
# 27   http://www.wikidata.org/entity/Q43465785
# 43    http://www.wikidata.org/entity/Q1534100
# 37    http://www.wikidata.org/entity/Q1286167
# 41    http://www.wikidata.org/entity/Q1534116
# 5     http://www.wikidata.org/entity/Q1534150
# 9   http://www.wikidata.org/entity/Q100263730
# 10  http://www.wikidata.org/entity/Q100263732
# 2    http://www.wikidata.org/entity/Q89492027
# 14   http://www.wikidata.org/entity/Q97466281
# 26   http://www.wikidata.org/entity/Q89280287
# 28   http://www.wikidata.org/entity/Q49321958
# 0     http://www.wikidata.org/entity/Q6215551
# 12  http://www.wikidata.org/entity/Q101415647
# 42    http://www.wikidata.org/entity/Q1534244
# 23   http://www.wikidata.org/entity/Q61001497
# 25   http://www.wikidata.org/entity/Q72662608
# 11  http://www.wikidata.org/entity/Q100936591
# 46   http://www.wikidata.org/entity/Q15857849
# 24   http://www.wikidata.org/entity/Q65768651
# 8    http://www.wikidata.org/entity/Q99727462
# 45   http://www.wikidata.org/entity/Q49350725
# 40    http://www.wikidata.org/entity/Q1534107
# 19   http://www.wikidata.org/entity/Q22290863
# 7    http://www.wikidata.org/entity/Q30447692
# 29    http://www.wikidata.org/entity/Q1534095
# 15   http://www.wikidata.org/entity/Q97487943
# 4    http://www.wikidata.org/entity/Q16831607
# 21   http://www.wikidata.org/entity/Q28053520
# 1    http://www.wikidata.org/entity/Q19695856
# 20   http://www.wikidata.org/entity/Q27162515
#
#                                                xLabel  \
# 39                                   Goethe-Gymnasium
# 36                       Goethe-Gymnasium Germersheim
# 31                                        Goethestein
# 34                                         Goetheturm
# 35                                        Goethewarte
# 32               Goethe-Universität Frankfurt am Main
# 18                                       Goethestraße
# 30                  Goethehäuschen auf dem Kickelhahn
# 22                                       Goethestraße
# 33                                         Goetheanum
# 6                                          Goetheanum
# 38                               Goethe-Schule Bochum
# 3                                      Goethe-Brunnen
# 16                                 Goethes Gartenhaus
# 44                        Goethe- und Schiller-Archiv
# 17                        Goethe-Gymnasium Regensburg
# 13                                       Goethestraße
# 27                                        Goetheplatz
# 43             Goethe-Freilichtbühne Porta Westfalica
# 37                         Goethegymnasium Hildesheim
# 41                        Goethe-Gymnasium Ibbenbüren
# 5                                      Goethe-Theater
# 9                                         Goetheplatz
# 10                                       Goethestraße
# 2                                           Goetheweg
# 14                            Goethestraße (Diepholz)
# 26                                       Goethestraße
# 28                                        Goetheplatz
# 0       Johann-Wolfgang-von-Goethe-Gymnasium Chemnitz
# 12                                         Goethering
# 42                                          Goetheweg
# 23                                        Goetheallee
# 25                                       Goethestraße
# 11                                       Goethestraße
# 46  Grundschule Pritzerbe „Johann Wolfgang von Goe...
# 24                                       Goethestraße
# 8                                        Goethestraße
# 45                           Herrenwalder Straße 1; 2
# 40                                   Goethe-Gymnasium
# 19                                       Goethestraße
# 7                            Ibn-Rushd-Goethe-Moschee
# 29                                     Goethe-Denkmal
# 15                                       Goethestraße
# 4                                          Goethepark
# 21                                       Goethestraße
# 1                             Goethe-Schule Flensburg
# 20                                        Goethegasse
#
#                             Location countryLabel  \
# 39     Point(8.62027778 49.69166667)  Deutschland
# 36     Point(8.37341944 49.21316111)  Deutschland
# 31            Point(8.16017 50.0625)  Deutschland
# 34         Point(8.711333333 50.089)  Deutschland
# 35            Point(8.24444 50.0931)  Deutschland
# 32   Point(8.651388888 50.119444444)  Deutschland
# 18            Point(6.47598 50.8002)  Deutschland
# 30            Point(10.8792 50.6664)  Deutschland
# 22          Point(11.44526 48.77222)  Deutschland
# 33         Point(7.620278 47.486111)      Schweiz
# 6              Point(7.62044 47.486)      Schweiz
# 38               Point(7.22 51.4864)  Deutschland
# 3             Point(11.2885 50.8984)  Deutschland
# 16            Point(11.3369 50.9761)  Deutschland
# 44            Point(11.3338 50.9831)  Deutschland
# 17        Point(12.073798 49.018051)  Deutschland
# 13          Point(10.45713 51.62174)  Deutschland
# 27      Point(10.5493947 51.7361062)  Deutschland
# 43             Point(8.90969 52.247)  Deutschland
# 37            Point(9.95667 52.1494)  Deutschland
# 41             Point(7.72139 52.275)  Deutschland
# 5             Point(11.8639 51.3883)  Deutschland
# 9            Point(9.72349 52.37268)  Deutschland
# 10           Point(9.72795 52.37416)  Deutschland
# 2           Point(12.70133 50.93311)  Deutschland
# 14       Point(8.3813607 52.6119962)  Deutschland
# 26          Point(12.90629 50.82352)  Deutschland
# 28          Point(12.90757 50.82208)  Deutschland
# 0         Point(12.942076 50.815887)  Deutschland
# 12  Point(13.166851882 50.652391243)  Deutschland
# 42        Point(12.233056 47.256944)   Österreich
# 23            Point(13.7953 51.0577)  Deutschland
# 25           Point(13.78386 51.1193)  Deutschland
# 11        Point(13.848995 51.128296)  Deutschland
# 46        Point(12.456924 52.494812)  Deutschland
# 24        Point(13.991655 51.524846)  Deutschland
# 8         Point(14.441383 51.175942)  Deutschland
# 45          Point(14.64875 50.87068)  Deutschland
# 40            Point(13.3216 52.4873)  Deutschland
# 19  Point(13.315730555 52.508886111)  Deutschland
# 7          Point(13.34944444 52.525)  Deutschland
# 29            Point(13.3764 52.5138)  Deutschland
# 15        Point(13.436993 52.552431)  Deutschland
# 4          Point(13.59054 52.677105)  Deutschland
# 21            Point(11.9001 54.1095)  Deutschland
# 1             Point(9.44289 54.7864)  Deutschland
# 20        Point(16.366915 48.203928)   Österreich
#
#                                      classdescription    distance
# 39                                          Gymnasium   25.248516
# 36                                          Gymnasium   31.265455
# 31                                           Skulptur   67.576896
# 34                                      Aussichtsturm   69.131842
# 35                                      Aussichtsturm   69.164213
# 32                             staatliche Universität   71.485674
# 18                                    Innerortsstraße  203.478314
# 30                                           Holzhaus  216.379562
# 22                                    Innerortsstraße  230.884789
# 33  Schulgebäude, Mehrzweckhalle, Verwaltungsgebäu...  231.135932
# 6                             Theater, Mehrzweckhalle  231.144617
# 38                                          Gymnasium  239.075309
# 3                                       Park, Brunnen  254.864264
# 16                        Museum, Einfamilienwohnhaus  262.806546
# 44                                    Literaturarchiv  263.114684
# 17                                          Gymnasium  266.974339
# 13                                    Innerortsstraße  275.818838
# 27                                              Platz  289.988922
# 43                                     Freilichtbühne  308.385386
# 37                                          Gymnasium  313.919404
# 41                                          Gymnasium  314.293601
# 5                                             Theater  320.198449
# 9                                     Innerortsstraße  332.656190
# 10                                    Innerortsstraße  332.897296
# 2                          Sackgasse, Innerortsstraße  341.484172
# 14                                    Innerortsstraße  347.448158
# 26                                    Innerortsstraße  349.389663
# 28                                Platz, Gesamtanlage  349.408527
# 0                                Schule, Schulgebäude  351.363592
# 12                                    Innerortsstraße  359.540080
# 42                                    Themenwanderweg  372.681532
# 23                                    Innerortsstraße  416.901588
# 25                                    Innerortsstraße  418.858276
# 11                                    Innerortsstraße  423.425807
# 46                                        Grundschule  435.547624
# 24                                    Innerortsstraße  451.492568
# 8                                     Innerortsstraße  463.631181
# 45                            ehemaliges Schulgebäude  466.162977
# 40                Gymnasium, humanistisches Gymnasium  475.986818
# 19                                    Innerortsstraße  477.321790
# 7                                    Moschee, Moschee  480.213133
# 29                                    Statue, Denkmal  480.712375
# 15                                    Innerortsstraße  486.635963
# 4                                                Park  503.650093
# 21                                    Innerortsstraße  565.404481
# 1            Schule, weiterführende Schule, Gymnasium  592.924135
# 20                                    Innerortsstraße  595.203703

# %% [markdown]
# ## Corresponding Map Query

# %%
queryAllResourcesMap = '''

<iframe style="width: 80vw; height: 50vh; border: none;" src="https://query.wikidata.org/embed.html#%20%20%20%20%23defaultView%3AMap%0A%20%20%20%20prefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0A%20%20%20%20prefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0A%20%20%20%20prefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0A%20%20%20%20prefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0A%20%20%20%20SELECT%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0A%20%20%20%20%20%20%20%20(GROUP_CONCAT(%3FclassLabel%3B%20separator%3D'%2C%20')%20AS%20%3Fclassdescription)%0A%0A%20%20%20%20WHERE%20%7B%0A%20%20%20%20%20%20%23%20x%20is%20named%20after%0A%20%20%20%20%20%20%3Fx%20wdt%3AP138%20<{somebody}>%20%3B%0A%0A%20%20%20%20%20%20%23%20x%20has%20location%0A%20%20%20%20%20%20%20%20%20wdt%3AP625%20%3FLocation%20%3B%0A%0A%20%20%20%20%20%20%23%20which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20%20%20%20%20wdt%3AP31%20%20%3Fclass%20.%20%0A%0A%20%20%20%20%20%20%23%20the%20class%20has%20a%20german%20label%20%0A%20%20%20%20%20%20%3Fclass%20rdfs%3Alabel%20%3FclassLabel%20.%0A%20%20%20%20%20%20FILTER%20(%20lang(%3FclassLabel)%20%3D%20%22en%22%20)%0A%0A%20%20%20%20%20%20%23%20located%20in%20Germany%2C%20Austria%2C%20or%20Switzerland%0A%20%20%20%20%20%20%3Fx%20wdt%3AP17%20%3Fcountry%20.%0A%20%20%20%20%20%20FILTER%20(%20%3Fcountry%20%3D%20wd%3AQ39%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ40%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ183%20)%0A%0A%20%20%20%20%20%20%23%20Retrieve%20Labels%0A%20%20%20%20%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22.%20%7D%0A%0A%20%20%20%20%7D%0A%20%20%20%20GROUP%20BY%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0A%20%20%20%20LIMIT%201000" referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>

'''.format(somebody=somebody)

# %%
queryAllResourcesNameSearchMap = '''

<iframe style="width: 80vw; height: 50vh; border: none;" src="https://query.wikidata.org/embed.html#%23defaultView%3AMap%0Aprefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0Aprefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0Aprefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0Aprefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0ASELECT%20%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0A(GROUP_CONCAT%20(DISTINCT%20%3FclassLabel%3B%20separator%3D'%2C%20')%20AS%20%3Fclassdescription)%0A%0AWHERE%20%7B%0A%20%20%3Fs%20wdt%3AP31%20wd%3AQ5%20%3B%0A%20%20%20%20%20rdfs%3Alabel%20%3FsLabel%20.%0A%20%20FILTER%20(regex(%3FsLabel%2C%20%22{somebodysName}%22)%20)%20%0A%0A%20%20%23%20x%20is%20named%20after%0A%20%20%3Fx%20wdt%3AP138%20%3Fs%20%3B%0A%0A%20%20%20%20%20%23%20x%20has%20location%0A%20%20%20%20%20wdt%3AP625%20%3FLocation%20%3B%0A%0A%20%20%20%20%20%23%20which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20wdt%3AP31%20%20%3Fclass%20.%20%0A%0A%20%20%23%20the%20class%20has%20a%20german%20label%20%0A%20%20%3Fclass%20rdfs%3Alabel%20%3FclassLabel%20.%0A%20%20FILTER%20(%20lang(%3FclassLabel)%20%3D%20%22en%22%20)%0A%0A%20%20%23%20located%20in%20Germany%2C%20Austria%2C%20or%20Switzerland%0A%20%20%3Fx%20wdt%3AP17%20%3Fcountry%20.%0A%20%20FILTER%20(%20%3Fcountry%20%3D%20wd%3AQ39%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ40%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ183%20)%0A%0A%20%20%23%20Retrieve%20Labels%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22.%20%7D%0A%0A%7D%0AGROUP%20BY%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0ALIMIT%201000" referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>

'''.format(somebodysName=somebodysName)

# %% [markdown]
# ###### CHANGES
#
# - 2. Query: Abstract (2. query added)
# - 2. Query: Abstract (updated method to handle results)
# - 3. Query: All named (updated to en instead od de)
# - 3. Query: All named (2nd query added)
# - Corresponding Map Query (updated to en instead od de)
# - Corresponding Map Query second query added

# %%
queryAllResourcesNameSearchMap
# Out:
# '\n\n<iframe style="width: 80vw; height: 50vh; border: none;" src="https://query.wikidata.org/embed.html#%23defaultView%3AMap%0Aprefix%20bd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0Aprefix%20wd%3A%20%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fentity%2F%3E%0Aprefix%20wdt%3A%20%20%20%20%20%20%3Chttp%3A%2F%2Fwww.wikidata.org%2Fprop%2Fdirect%2F%3E%0Aprefix%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0A%0A%0ASELECT%20%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0A(GROUP_CONCAT%20(DISTINCT%20%3FclassLabel%3B%20separator%3D\'%2C%20\')%20AS%20%3Fclassdescription)%0A%0AWHERE%20%7B%0A%20%20%3Fs%20wdt%3AP31%20wd%3AQ5%20%3B%0A%20%20%20%20%20rdfs%3Alabel%20%3FsLabel%20.%0A%20%20FILTER%20(regex(%3FsLabel%2C%20%22Konrad Adenauer%22)%20)%20%0A%0A%20%20%23%20x%20is%20named%20after%0A%20%20%3Fx%20wdt%3AP138%20%3Fs%20%3B%0A%0A%20%20%20%20%20%23%20x%20has%20location%0A%20%20%20%20%20wdt%3AP625%20%3FLocation%20%3B%0A%0A%20%20%20%20%20%23%20which%20Class%20is%20x%20(e.g.%20Street%2C%20church)%0A%20%20%20%20%20wdt%3AP31%20%20%3Fclass%20.%20%0A%0A%20%20%23%20the%20class%20has%20a%20german%20label%20%0A%20%20%3Fclass%20rdfs%3Alabel%20%3FclassLabel%20.%0A%20%20FILTER%20(%20lang(%3FclassLabel)%20%3D%20%22en%22%20)%0A%0A%20%20%23%20located%20in%20Germany%2C%20Austria%2C%20or%20Switzerland%0A%20%20%3Fx%20wdt%3AP17%20%3Fcountry%20.%0A%20%20FILTER%20(%20%3Fcountry%20%3D%20wd%3AQ39%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ40%20%7C%7C%20%3Fcountry%20%3D%20wd%3AQ183%20)%0A%0A%20%20%23%20Retrieve%20Labels%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22.%20%7D%0A%0A%7D%0AGROUP%20BY%20%3Fx%20%3FxLabel%20%3FLocation%20%3FcountryLabel%0ALIMIT%201000" referrerpolicy="origin" sandbox="allow-scripts allow-same-origin allow-popups"></iframe>\n\n'
